# %% [markdown]
# <a href="https://colab.research.google.com/github/khushi3117/Python-Projects/blob/main/3NPV_in_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="20%">
#             <img src="GL-2.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b>Inclass - Lab<br> (Week 3)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Table of Content
# 1. **[Reshape](#Reshape)[Learning material]**
# 2. **[Pivot Table](#Pivoting)**
# 3. **[Duplicate](#Duplicating)**
# 4. **[Replace](#Replacing)**
# 5. **[Index](#Indexing)**
# 6. **[Merge, Join, Concatenate](#merge)[ Prerequisite]**
# 7. **[Plots using Library Matplotlib ](#matplotlib)**
# 8. **[Plots using Library Seaborn ](#seaborn)[Self Learning material]**
# 9. **[Plots using Library Plotly](#plotly)[Self Learning material]**

# %% [markdown]
# **Let us import the required library**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id='Reshape'></a>
# ## 1. Reshape[Learning material]

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 1. Write a program to reshape the given dataframe using the melt function, considering 'Day' as the identifier variable
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Day</th>
# <th>ICICI</th>
# <th>HDFC</th>
# </tr>
# <tr>
# <td>MON</td>
# <td>1129</td>
# <td>191</td>
# </tr>
# <tr>
# <td>TUES</td>
# <td>1132</td>
# <td>192</td>
# </tr>
# <tr>
# <td>WED</td>
# <td>1134</td>
# <td>190</td>
# </tr>
# <tr>
# <td>THU</td>
# <td>1152</td>
# <td>190</td>
# </tr>
# <tr>
# <td>FRI</td>
# <td>1152</td>
# <td>188</td>
# </tr>
#
# </table>

# %%
import pandas as pd
Table=pd.DataFrame({'Day':['Mon','Tue','Wed','Thu','Fri','Sat'],
'ICICI':[1129,1132,1134,1152,1152,1143],
'HDFC':[191,192,190,190,188,188]})
Table
# Out:
#    Day  ICICI  HDFC
# 0  Mon   1129   191
# 1  Tue   1132   192
# 2  Wed   1134   190
# 3  Thu   1152   190
# 4  Fri   1152   188
# 5  Sat   1143   188

# %%
Melted=pd.melt(Table, id_vars=['Day'], var_name='metric', value_name='value')
Melted
# Out:
#     Day metric  value
# 0   Mon  ICICI   1129
# 1   Tue  ICICI   1132
# 2   Wed  ICICI   1134
# 3   Thu  ICICI   1152
# 4   Fri  ICICI   1152
# 5   Sat  ICICI   1143
# 6   Mon   HDFC    191
# 7   Tue   HDFC    192
# 8   Wed   HDFC    190
# 9   Thu   HDFC    190
# 10  Fri   HDFC    188
# 11  Sat   HDFC    188

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 2. Stack the dataframe at institute level
#                     <br>
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
# <img src="que2.png">

# %%
import pandas as pd
institute_table=pd.DataFrame({'institute':['IIT','NIT','IGNOU'],
'COURSES':['java','python','data analysis']})
institute_table
# Out:
#   institute        COURSES
# 0       IIT           java
# 1       NIT         python
# 2     IGNOU  data analysis

# %%
#first set institute as the index
institute_table.set_index('institute',inplace=True)

# %%
#now stak the table at institute level
print(institute_table.stack())
# Out:
# institute
# IIT        COURSES             java
# NIT        COURSES           python
# IGNOU      COURSES    data analysis
# dtype: object

# %% [markdown]
# <a id='Pivoting'></a>
# ## 2. Pivot Table

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 3. Find the average sales for each store
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
import pandas as pd
Store_data=pd.DataFrame({'Store':['A','B','C','D','E','F','A','B','C'],
'Location':['Mumbai','Pune','Delhi','Hyderabad','Mumbai','Delhi','pune','Delhi','pune'],
'Sales':[45000,40000,35000,45000,50000,54000,34000,440000,33000]})
Store_data
# Out:
#   Store   Location   Sales
# 0     A     Mumbai   45000
# 1     B       Pune   40000
# 2     C      Delhi   35000
# 3     D  Hyderabad   45000
# 4     E     Mumbai   50000
# 5     F      Delhi   54000
# 6     A       pune   34000
# 7     B      Delhi  440000
# 8     C       pune   33000

# %%
Store_data['average_sales']=Store_data['Sales'].mean()
Store_data
# Out:
#   Store   Location   Sales  average_sales
# 0     A     Mumbai   45000   86222.222222
# 1     B       Pune   40000   86222.222222
# 2     C      Delhi   35000   86222.222222
# 3     D  Hyderabad   45000   86222.222222
# 4     E     Mumbai   50000   86222.222222
# 5     F      Delhi   54000   86222.222222
# 6     A       pune   34000   86222.222222
# 7     B      Delhi  440000   86222.222222
# 8     C       pune   33000   86222.222222

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 4. Compute the average sales for each store in every city
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
Store_data['average_sales_city']=Store_data.groupby(['Store','Location'])['Sales'].transform('mean')
Store_data
# Out:
#   Store   Location   Sales  average_sales  average_sales_city
# 0     A     Mumbai   45000   86222.222222             45000.0
# 1     B       Pune   40000   86222.222222             40000.0
# 2     C      Delhi   35000   86222.222222             35000.0
# 3     D  Hyderabad   45000   86222.222222             45000.0
# 4     E     Mumbai   50000   86222.222222             50000.0
# 5     F      Delhi   54000   86222.222222             54000.0
# 6     A       pune   34000   86222.222222             34000.0
# 7     B      Delhi  440000   86222.222222            440000.0
# 8     C       pune   33000   86222.222222             33000.0

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 5. Compute the minimum sales for each store in every city
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Store</th>
# <th>Location</th>
# <th>Sales</th>
# </tr>
# <tr>
# <td>A</td>
# <td>Mumbai</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>45000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Hyderabad</td>
# <td>50000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>90000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Pune</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Delhi</td>
# <td>87000</td>
# </tr>
# <tr>
# <td>D</td>
# <td>Hyderabad</td>
# <td>85000</td>
# </tr>
# <tr>
# <td>A</td>
# <td>Pune</td>
# <td>78000</td>
# </tr>
# <tr>
# <td>C</td>
# <td>Mumbai</td>
# <td>89000</td>
# </tr>
# <tr>
# <td>B</td>
# <td>Pune</td>
# <td>70000</td>
# </tr>
#
# </table>

# %%
Store_data['min_sales']=Store_data.groupby(['Store','Location'])['Sales'].transform('min')
Store_data
# Out:
#   Store   Location   Sales  average_sales  average_sales_city  min_sales
# 0     A     Mumbai   45000   86222.222222               45000      45000
# 1     B       Pune   40000   86222.222222               40000      40000
# 2     C      Delhi   35000   86222.222222               35000      35000
# 3     D  Hyderabad   45000   86222.222222               45000      45000
# 4     E     Mumbai   50000   86222.222222               50000      50000
# 5     F      Delhi   54000   86222.222222               54000      54000
# 6     A       pune   34000   86222.222222               34000      34000
# 7     B      Delhi  440000   86222.222222              440000     440000
# 8     C       pune   33000   86222.222222               33000      33000

# %%
Store_data.min()
# Out:
# Store                            A
# Location                     Delhi
# Sales                        33000
# average_sales         86222.222222
# average_sales_city           33000
# min_sales                    33000
# dtype: object

# %% [markdown]
# <a id='Duplicating'></a>
# ## 3. Duplicate

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 6. Find duplicate rows in the data
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
Store_data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 7. Select duplicate rows, except the last occurrence
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Salary</th>
# <th>City</th>
# </tr>
# <tr>
# <td>John</td>
# <td>3400</td>
# <td>Sydeny</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>1600</td>
# <td>New York</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Texas</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>4000</td>
# <td>London</td>
# </tr>
# <tr>
# <td>Sachine</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
#
# </table>

# %%
import pandas as pd
Store_data=pd.DataFrame({'Name':['Jhon','Robert','Aadi','Robert','Aadi','Sachin'],
                         'City':['sydney','chicago','London','chicago','London','chicago'],
'Salary':[45000,40000,33000,40000,33000,55000]})
Store_data
# Out:
#      Name     City  Salary
# 0    Jhon   sydney   45000
# 1  Robert  chicago   40000
# 2    Aadi   London   33000
# 3  Robert  chicago   40000
# 4    Aadi   London   33000
# 5  Sachin  chicago   55000

# %%
#Select duplicate rows, except the last occurrence
Store_data.duplicated(keep='last')
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# 5    False
# dtype: bool

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 8.  Select the duplicated rows based on the column names 'Salary' and 'City'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
duplicates_column = Store_data[Store_data.duplicated(subset=['Salary','City'])]
print(duplicates_column)
# Out:
#      Name     City  Salary
# 3  Robert  chicago   40000
# 4    Aadi   London   33000

# %% [markdown]
# # **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Salary</th>
# <th>City</th>
# </tr>
# <tr>
# <td>John</td>
# <td>3400</td>
# <td>Sydeny</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>1600</td>
# <td>New York</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>3000</td>
# <td>Texas</td>
# </tr>
# <tr>
# <td>Aadi</td>
# <td>4000</td>
# <td>London</td>
# </tr>
# <tr>
# <td>Sachine</td>
# <td>3000</td>
# <td>Chicago</td>
# </tr>
#
# </table>

# %% [markdown]
# <a id='Replacing'></a>
# ## 4. Replace

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 9.  Replace 'football' with 'hockey' in the column tournament
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table>
# <tr>
# <th>Days</th>
# <th>Tournament</th>
# </tr>
# <tr>
# <td>Mon</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Tues</td>
# <td>Cricket</td>
# </tr>
# <tr>
# <td>Wed</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Thurs</td>
# <td>Football</td>
# </tr>
# <tr>
# <td>Fri</td>
# <td>Cricket</td>
# </tr>
#
# </table>

# %%
import pandas as pd
DAY_Tournament=pd.DataFrame({'Days':['Mon','Tue','Wed','Thu','Fri','sat'],
                         'Tournament':['Football','Cricket','Football','Football','Football','Cricket']})
DAY_Tournament
# Out:
#   Days Tournament
# 0  Mon   Football
# 1  Tue    Cricket
# 2  Wed   Football
# 3  Thu   Football
# 4  Fri   Football
# 5  sat    Cricket

# %%
Tournament=DAY_Tournament.replace({'Football':'Hockey'})
#DAY_Tournament.replace(to_replace:'Football',value:'Hockey')
print(Tournament)
# Out:
#   Days Tournament
# 0  Mon     Hockey
# 1  Tue    Cricket
# 2  Wed     Hockey
# 3  Thu     Hockey
# 4  Fri     Hockey
# 5  sat    Cricket

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 10.  Replace all 0's with male and all 1's with female in the gender column
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>Num_Children</th>
# <th>Gender</th>
# </tr>
# <tr>
# <td>John</td>
# <td>0</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>4</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Johny</td>
# <td>5</td>
# <td>0</td>
# </tr>
# <tr>
# <td>Mia</td>
# <td>3</td>
# <td>1</td>
# </tr>
#
# </table>

# %%
import pandas as pd
df=pd.DataFrame({'Name' : ['Jhon','Robert','Jhony','Mia'],
                 'Days' : ['Mon','Tue','wed','Thu'],
                'Num_children': [0,4,5,3],
                'Gender':[0,0,0,1]})
df
# Out:
#      Name Days  Num_children  Gender
# 0    Jhon  Mon             0       0
# 1  Robert  Tue             4       0
# 2   Jhony  wed             5       0
# 3     Mia  Thu             3       1

# %%
# Replace all 0's with male and all 1's with female in the gender column
data_table=data_table.Gender.replace({0:'Male',1:'Female'})

# %%
data_table
# Out:
# 0      Male
# 1      Male
# 2      Male
# 3    Female
# Name: Gender, dtype: object

# %% [markdown]
# <a id='Indexing'></a>
# ## 5. Index

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 11.  Set 'Name' and 'City' columns as indices for the below dataframe
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>Name</th>
# <th>City</th>
# <th>Sales</th>
# <th>Expenses</th>
# </tr>
# <tr>
# <td>John</td>
# <td>New York</td>
# <td>60000</td>
# <td>12000</td>
# </tr>
# <tr>
# <td>Robert</td>
# <td>Chicago</td>
# <td>42000</td>
# <td>33000</td>
# </tr>
# <tr>
# <td>Jony</td>
# <td>Texas</td>
# <td>50000</td>
# <td>40000</td>
# </tr>
# <tr>
# <td>Mia</td>
# <td>California</td>
# <td>24000</td>
# <td>34000</td>
# </tr>
# <tr>
# <td>Edward</td>
# <td>Sydney</td>
# <td>12000</td>
# <td>28000</td>
# </tr>
# <tr>
# <td>Thomas</td>
# <td>New York</td>
# <td>82000</td>
# <td>19000</td>
# </tr>
# <tr>
# <td>Ethan</td>
# <td>Chicago</td>
# <td>59000</td>
# <td>32000</td>
# </tr>
# <tr>
# <td>Olivia</td>
# <td>Sydeney</td>
# <td>85000</td>
# <td>10000</td>
# </tr>
# <tr>
# <td>Arun</td>
# <td>California</td>
# <td>97000</td>
# <td>49000</td>
# </tr>
# <tr>
# <td>Ankita</td>
# <td>Texas</td>
# <td>35000</td>
# <td>34000</td>
# </tr>
# <tr>
# <td>Paulo</td>
# <td>Chicago</td>
# <td>47000</td>
# <td>55000</td>
# </tr>
#
# </table>

# %%
#Set 'Name' and 'Gender' columns as indices for the below dataframe
import pandas as pd
df=pd.DataFrame({'Name' : ['Jhon','Robert','Jhony','Mia'],
                'Num_children': [0,4,5,3],
                'Gender':[0,0,0,1]})
df
# Out:
#      Name  Num_children  Gender
# 0    Jhon             0       0
# 1  Robert             4       0
# 2   Jhony             5       0
# 3     Mia             3       1

# %%
df.set_index(['Name', 'Gender'], inplace=True)
df
# Out:
#                Num_children
# Name   Gender
# Jhon   0                  0
# Robert 0                  4
# Jhony  0                  5
# Mia    1                  3

# %%
type(data_table)
# Out:
# pandas.core.series.Series

# %% [markdown]
# <a id='merge'></a>
# ## 6. Merge, Join, Concatenate[Prerequisite]

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 12. Merge the given dataframes on the column 'Brand'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# **Use the dataframe given below:**
#
# <table>
# <tr>
# <th>ID</th>
# <th>Brand</th>
# <th>Product</th>
# </tr>
# <tr>
# <td>101</td>
# <td>Apple</td>
# <td>iPhone</td>
# </tr>
# <tr>
# <td>102</td>
# <td>Canon</td>
# <td>DSLR</td>
# </tr>
# <tr>
# <td>103</td>
# <td>Samsung</td>
# <td>SmartPhone</td>
# </tr>
# <tr>
# <td>104</td>
# <td>Nikon</td>
# <td>DSLR</td>
# </tr>
# <td>105</td>
# <td>Sony</td>
# <td>SmartTV</td>
# </tr>
#
# </table><br>
#
# <table>
# <tr>
#     <th>ID</th>
# <th>Brand</th>
# <th>Quantity_sold</th>
# </tr>
# <tr>
#     <td>101</td>
# <td>Apple</td>
# <td>234</td>
# </tr>
# <tr>
#     <td>102</td>
# <td>Canon</td>
# <td>344</td>
# </tr>
# <tr>
#     <td>104</td>
# <td>Samsung</td>
# <td>345</td>
# </tr>
# <tr>
#     <td>103</td>
# <td>Nikon</td>
# <td>262</td>
# </tr>
#     <td>105</td>
# <td>Sony</td>
# <td>356</td>
# </tr>
# </table>

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({'Name' : ['Jhon','Robert','Jhony','Mia'],
                 'Days' : ['Mon','Tue','wed','Thu'],
                'Num_children': [0,4,5,3],
                'Gender':[0,0,0,1]})
df
DAY_Tournament=pd.DataFrame({'Days':['Mon','Tue','Wed','Thu','Fri','sat'],
                         'Tournament':['Football','Cricket','Football','Football','Football','Cricket']})
DAY_Tournament
pd.merge(df,DAY_Tournament, on='Days')
# Out:
#      Name Days  Num_children  Gender Tournament
# 0    Jhon  Mon             0       0   Football
# 1  Robert  Tue             4       0    Cricket
# 2     Mia  Thu             3       1   Football

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 13. Using the dataframes created in question 16, merge the given dataframes by 'ID' and 'Brand'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({'Name' : ['Jhon','Robert','Jhony','Mia'],
                 'Days' : ['Mon','Tue','wed','Thu'],
                'Num_children': [0,4,5,3],
                'Gender':[0,0,0,1]})
df
DAY_Tournament=pd.DataFrame({'Days':['Mon','Tue','Wed','Thu','Fri','sat'],
                             'Name' : ['Jhon','Robert','Jhony','Mia','kalia','mohan'],
                         'Tournament':['Football','Cricket','Football','Football','Football','Cricket']})
DAY_Tournament
pd.merge(df,DAY_Tournament, on=['Days','Name'])
# Out:
#      Name Days  Num_children  Gender Tournament
# 0    Jhon  Mon             0       0   Football
# 1  Robert  Tue             4       0    Cricket
# 2     Mia  Thu             3       1   Football

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 14. Using the dataframes created in question 16, perform left join to combine values in the columns 'Brand' and 'ID'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 15. Using the dataframes created in question 16, perform outer join to combine values in the columns 'Brand' and 'ID'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left">
#                 <font color="#21618C" size=4px>
#                     <b> 16. Concatenate rows of the given dataframes and assign the store as its key
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
#                            Products in Store_A:
# <table>
#     <tr>
#         <th>ID</th>
#         <th>Brand</th>
#         <th>Product</th>
#     </tr>
#     <tr>
#         <td>101</td>
#         <td>Apple</td>
#         <td>iPhone</td>
#         </tr>
#     <tr>
#         <td>102</td>
#         <td>Canon</td>
#         <td>DSLR</td>
#     </tr>
#     <tr>
#         <td>103</td>
#         <td>Samsung</td>
#         <td>SmartPhone</td>
#     </tr>
#     <tr>
#         <td>104</td>
#         <td>Nikon</td>
#         <td>DSLR</td>
#   </tr>
#       <td>105</td>
#       <td>Sony</td>
#       <td>SmartTV</td>
#   </tr>
# </table>

# %% [markdown]
#                           Products in Store_B:
# <table>
#     <tr>
#         <th>ID</th>
#         <th>Brand</th>
#         <th>Product</th>
#     </tr>
#     <tr>
#         <td>103</td>
#         <td>Apple</td>
#         <td>iPhone</td>
#         </tr>
#     <tr>
#         <td>104</td>
#         <td>Apple</td>
#         <td>iPod</td>
#     </tr>
#     <tr>
#         <td>104</td>
#         <td>Samsung</td>
#         <td>SmartPhone</td>
#     </tr>
#     <tr>
#         <td>107</td>
#         <td>Canon</td>
#         <td>DSLR</td>
#   </tr>
#       <td>101</td>
#       <td>Sony</td>
#       <td>SmartTV</td>
#   </tr>
# </table>

# %%
# create a dataframe

# %% [markdown]
# <a id='matplotlib'></a>
# ## 7. Plots using Library Matplotlib

# %% [markdown]
# ### Let us import the required libraries.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.figure_factory as ff
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# ### a. Scatter Plots

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>17. Plot a scatter plot for the following data. Also add title and axis names</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
#             bmi = (18, 34, 54, 45, 45, 45, 23, 23, 54)
#             medical_claim = (145, 456, 764, 234, 156, 786, 345, 455, 675)

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>18. Write a code to get the following output </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# <img src="cos_curve.png" width = '500' >

# %%
# G

# %%
# set the plot size
plt.figure(figsize=(12,8))

# create the variable x using linspace()
x = np.linspace(0, 20, 100)

# create the variable y taking
y = np.cos(x)

# plot the data using the plot()
plt.plot(x, y, '-ok', color='black')

# add plot title
# fontsize sets the size of the title
plt.title("Cosine Curve", fontsize=30)

# add x-axis label
# fontsize sets the size of the label
plt.xlabel("x", fontsize=20)

# add y-axis label
# fontsize sets the size of the label
plt.ylabel( "Cosine(x)", fontsize=20)

# display the plot
plt.show()
# Out:
# C:\Users\vijay\AppData\Local\Temp/ipykernel_5724/3705950314.py:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(x, y, '-ok', color='black')

# %%
x = np.linspace(0, 20, 100)
y = np.cos(x)
y
# Out:
# array([ 1.        ,  0.97966323,  0.91948007,  0.8218984 ,  0.69088721,
#         0.53177518,  0.35103397,  0.15601496, -0.04534973, -0.24486989,
#        -0.43443032, -0.60632092, -0.75355031, -0.87013012, -0.95131866,
#        -0.9938137 , -0.9958868 , -0.95745366, -0.88007748, -0.76690542,
#        -0.6225406 , -0.45285485, -0.26474988, -0.06587659,  0.13567613,
#         0.33171042,  0.51425287,  0.67587883,  0.8100144 ,  0.91120382,
#         0.97533134,  0.99978867,  0.98358105,  0.9273677 ,  0.83343502,
#         0.70560358,  0.54907273,  0.37020915,  0.17628785, -0.0248037 ,
#        -0.2248864 , -0.41582217, -0.58984498, -0.7398767 , -0.859815  ,
#        -0.94478159, -0.99132055, -0.99753899, -0.96318398, -0.88965286,
#        -0.7799364 , -0.63849716, -0.47108797, -0.28451797, -0.08637561,
#         0.11527995,  0.31224667,  0.4965132 ,  0.66058479,  0.79778804,
#         0.90254243,  0.97058721,  0.99915477,  0.98708316,  0.93486337,
#         0.84461938,  0.72002171,  0.56613821,  0.38922786,  0.19648623,
#        -0.00424719, -0.20480786, -0.39703827, -0.57311973, -0.72589037,
#        -0.84913647, -0.93784519, -0.98840841, -0.99876955, -0.9685072 ,
#        -0.89885222, -0.79263773, -0.65418385, -0.48912199, -0.30416581,
#        -0.10683812,  0.09483505,  0.29265094,  0.47856368,  0.64501154,
#         0.78522449,  0.89349958,  0.96543286,  0.99809857,  0.99016807,
#         0.94196391,  0.85544675,  0.73413553,  0.58296441,  0.40808206])

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>19. Create a bubble plot. Further use the parameter 'alpha' to adjust the transparency level. (Generate the data using random number)</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# **Note:** A bubble chart is a type of scatter plot that represents three dimensional data. The third variable is represented by the size of a point (marker).

# %%
# set the plot size
plt.figure(figsize=(8,8))

# set the random state
rnd = np.random.RandomState(5)

# generate the data using random numbers
x = rnd.randn(35)
y = rnd.randn(35)
sizes = 1000 * rnd.rand(35)
plt.scatter(x, y,  s=sizes, alpha=0.5)

# display the plot
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 20. Plot cosine curve and exponential curve for natural numbers from 0.1 to 20, in the same plot (get the following output)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
# <img src="dual_axis.png" width ='500' >

# %%
x = np.arange(0.1,5,0.01)

# let variable y1 be the exponential of values in x
y1 = np.exp(x)

# let variable y2 be the cosine of values in x
y2 = np.cos(2 * np.pi * x)

#exponential code
fig, ax1 = plt.subplots()
ax1.plot(x, y1, color= 'tab:blue' )
ax1.tick_params(axis='y', labelcolor='tab:blue')
ax1.set_ylabel('Exp(x)', color='tab:blue', fontsize = 10)
#cos code
ax2 = ax1.twinx()
ax2.plot(x, y2, color='tab:red')
ax2.tick_params(axis='y', labelcolor='tab:red')
ax2.set_ylabel('Cos(x)', color = 'tab:red', fontsize = 10)

ax1.set_xlabel('X')
plt.show()

# %% [markdown]
# ### b. Barplots

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 21. The exports and imports (in billion dollars) is given for a country from 2001 to 2005. Draw a barplot for the data
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table>
#   <tr>
#   <th>Year</th>
#   <th>Import</th>
#   <th>Export</th>
#   </tr>
#   <tr>
#   <td>2001</td>
#   <td>54.4</td>
#   <td>42.5 </td>
#   </tr>
#   <tr>
#   <td>2002</td>
#   <td>53.8</td>
#   <td>44.5</td>
#   </tr>
#   <tr>
#   <td>2003</td>
#   <td>61.6</td>
#   <td>48.3</td>
#   </tr>
#   <tr>
#   <td>2004</td>
#   <td>74.15</td>
#   <td>57.24</td>
#   </tr>
#   <tr>
#   <td>2005</td>
#   <td>89.33</td>
#   <td>69.18</td>
#   </tr>
# </table>

# %%
# create a list of years
year = ['2001', '2002', '2003', '2004', '2005']

# create a list of imports
imports = (54.4, 53.8, 61.6, 74.15, 89.33)

# create a list of exports
exports = (42.5, 44.5, 48.3, 57.24, 69.18)

# %%
# the label positions
x = np.arange(len(year))

# set the bar width
width = 0.4

# initiate the plot
fig, ax = plt.subplots()

# set the bars
bars1 = ax.bar(x - width/2, imports, width, label='Imports')
bars2 = ax.bar(x + width/2, exports, width, label='Exports')

# add title for plot
plt.title('Imports and Exports from 2001-05')

# add label the axes
# add label to x-axis
plt.xlabel('Year')

# add label to y-axis
plt.ylabel('USD (in billions)')

# add xticks
plt.xticks([tick for tick in range(len(bars1))], year)

# add the legend
plt.legend()

# display the plot
plt.show()

# %% [markdown]
# ### c. Pie plots

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 22. Plot a pie chart for the following data
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
#         prices = [50, 25, 50, 20]
#         labels = ['Apple', 'Orange','Banana', 'Mango']

# %%
prices = [50, 25, 50, 20]
labels = ['Apple', 'Orange','Banana', 'Mango']
plt.pie(prices,labels=labels,autopct='%.f%%')
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 23. Following is the information release after the Indian budget is declared. Plot a donut chart for it
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table>
#   <tr>
#   <th>Income Form </th>
#   <th>Amount (in paise)</th>
#   </tr>
#   <tr>
#   <td>Corporation Tax</td>
#   <td>21</td>
#   </tr>
#   <tr>
#   <td>Income Tax</td>
#   <td>16</td>
#   </tr>
#   <tr>
#   <td>Customs</td>
#   <td>4</td>
#   </tr>
#   <tr>
#   <td>Union Excise Duties</td>
#   <td>8</td>
# </tr>
#   <tr>
#   <td>GST & Other Taxes</td>
#   <td>19</td>
# </tr>
# <tr>
#   <td>Non-Tax Revenue</td>
#   <td>9</td>
#   </tr>
#   <tr>
#   <td>Non-Debt Capital Receipts</td>
#   <td>3</td>
# </tr>
#   <tr>
#   <td>Borrowings and Other Liabilities</td>
#   <td>20</td>
#   </tr>
# </table>

# %%
income = ['Corporation Tax', 'Income Tax', 'Customs', 'Union Excise Duties', 'GST & Other Taxes',
          'Non-Tax Revenue' , 'Non-Debt Capital Receipts', 'Borrowings and Other Liabilities']
amount = [21,16,4,8,19,9,3,20]

# set plot size
plt.figure(figsize=(7,7))
# create the circle for the center of the plot
# (0,0) specifies the center of the plot
# radius specifies the radius of the plot
# specifies the colour of the plot
my_circle = plt.Circle((0,0), radius = 0.5, color='white')

# plot the pie chart
# amount is the data
# labels are the labels given to each wedge
# wedgeprops are the wedge properties
# linewidth specifies the width of each line
# white is the colour of the edge
plt.pie(amount, labels = income, wedgeprops = { 'linewidth' : 7, 'edgecolor' : 'white' })

# set title of the plot
# fontsize specifies the plot size
plt.title("Where a rupee comes from?", fontsize = 20)

# plotting a donut plot
# gcf() gets the current figure
donut = plt.gcf()

# place the white circle 'my_circle' on it
donut.gca().add_artist(my_circle)

# display the plot
plt.show()

# %% [markdown]
# ### d. Line plots

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 24. Create a tuple of numbers 12, 34, 54, 45, 45, 45, 23, 23, 54 and plot a simple line plot
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
tup=[12,34,54,45,45,45,23,23,54]
plt.plot(tup)
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 25. Import the 'Returns.csv'. Plot a multiple line plot for the returns of each company
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
import pandas as pd
df_returns=pd.read_csv('C:/Users/vijay/Downloads/NPV Inclass Week3_ r/NPV Inclass Week3/Returns.csv')
df_returns.head()
# set the figure size
plt.figure(figsize=(15,8))

# select the style of the plot
plt.style.use('seaborn-darkgrid')

# select a color palette
colors = plt.get_cmap('Set1')

# plotting multiple line plot
# plot the multiplt line plot using the for loop

num=0
for column in df_returns.drop('Day', axis=1):
    num+=1
    plt.plot(df_returns['Day'], df_returns[column], marker='', color= colors(num), linewidth=1, alpha=0.9, label=column)


# add legend
plt.legend(loc=2, ncol=2)

# add titles
# loc specifies the location of the title
# fontsize specifies the fontsize of the title
# color specifies the color of the title
plt.title("Plot of Returns", loc='center', fontsize=22, color='black')

# add x-axis label
# fontsize specifies the fontsize of the label
plt.xlabel("Day", fontsize = 15)

# add y-axis label
# fontsize specifies the fontsize of the label
plt.ylabel("Returns", fontsize = 15)

# display the plot
plt.show()

# %% [markdown]
# <a id='seaborn'></a>
# ## 8. Plots using Library Seaborn[ Self Learning material]

# %% [markdown]
# import the seaborn library as sns.
#
# Check for the available datasets in it.

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 26. Plot a  strip plot using inbuilt data-set 'iris' given in seaborn
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(15,8))

# style=”whitegrid”  is used to define the background of plot
# an alternative is “darkgrid”
sns.set(style ="whitegrid")

# load the iris data set as iris
iris = sns.load_dataset('iris')

# plot the strip plot
# x specifies the data on x axis
# y specifies the data on y axis
# data is the dataset to be used
sns.stripplot(x = 'species', y = 'sepal_length', data = iris)

# add title
plt.title('Strip Plot')

# display the plot
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 27. Import the dataset age_height.csv. Plot a heat map for the correlation matrix
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# import the data
df_age_height = pd.read_csv('age_height.csv')

# set the figure size
plt.figure(figsize=(10,5))

# compute correlaion matrix
corr =  df_age_height.corr()
sns.heatmap(corr, cmap='RdYlGn', vmax=1.0, vmin=-1.0, annot = True, annot_kws={"size": 12} )

# display the plot
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 28. Plot a  swarmplot using inbuilt data-set 'iris' given in seaborn
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.figure(figsize=(10,5))

# style=”whitegrid”  is used to define the background of plot
# an alternative is “darkgrid”
#sns.set(style ="whitegrid")

# load the iris data set as iris
iris = sns.load_dataset('iris')

# plot the strip plot
# x specifies the data on x axis
# y specifies the data on y axis
# data is the dataset to be used
sns.swarmplot(x = 'species', y = 'sepal_length', data = iris)

# add title
plt.title('Swarm Plot')

# display the plot
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 28a. Using the following data, plot a scatter plot with  the function available in seaborn
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
#             x = (12, 34, 54, 45, 45, 45, 23, 23, 54)
#             y = (145, 456, 764, 234, 156, 786, 345, 455, 675)

# %%
x = (12, 34, 54, 45, 45, 45, 23, 23, 54)
y = (145, 456, 764, 234, 156, 786, 345, 455, 675)
plt.figure(figsize=(10,5))
sns.scatterplot(x=x,y=y)
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 28b. Using the data generated in question 3, plot a scatter plot with the function available in seaborn
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# set plot size
plt.figure(figsize=(10,5))

# set state random state
rnd = np.random.RandomState(5)

# generate data
x = rnd.randn(35)
y = rnd.randn(35)
sizes = 10 * rnd.rand(35)

# set the colors to be used
# cubehelix_palette() makes a sequential palette from the cubehelix system
# dark specifies the intensity of the darkest color in the palette.
# light specifies the intensity of lightest color in the palette.
# as_camp returns a matplotlib colormap if true
colors = sns.cubehelix_palette(dark=1, light=.5, as_cmap=True)
# plot the scatterplot
sns.scatterplot(x = x, y = y , size= sizes, palette=colors)

# display the plot
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 29. Using the 'diamonds' data available in the library seaborn, consider the price for the type of cut. Display the data using the following plots:
#                         <ol>
#                             <li> Multiple boxplot</li>
#                             <li> Violin Plot </li>
#                             <li> Boxen Plot </li>
#                         </ol>
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
diamonds = sns.load_dataset('diamonds')
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.catplot(x = "cut", y = "price", kind="box", data = diamonds)

# %%
sns.catplot(x = "cut", y = "price", kind="violin", data = diamonds)

# %%
sns.boxenplot(x = "cut", y = "price", data = diamonds)
plt.figure(figsize=(10,5))

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 30. Generate random number form normal distribution, plot the following:
#                         <ol>
#                             <li> Histogram</li>
#                             <li> Histogram with frequency curve </li>
#                         </ol>
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
x=np.random.normal(size=100)

# %%
sns.displot(x,kde=False)

# %%
sns.displot(x,kde=True)

# %% [markdown]
# <a id='plotly'></a>
# ## 9. Plots using Library Plotly[ Self Learning material]

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 31. Use the 'diamonds' data set from seaborn to plot the histogram of price by colors
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
diamonds = sns.load_dataset('diamonds')
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
fig = px.histogram(data_frame = diamonds, x="price", color="color")

# display the plot
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5724/4053007906.py in <module>
# ----> 1 fig = px.histogram(data_frame = diamonds, x="price", color="color")
#       2
#       3 # display the plot
#       4 fig.show()
#
# NameError: name 'px' is not defined

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 32. Plot a histrogram for 500 random numbers which have mean 0 and variance 1
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
x=np.random.seed(500)
fig = ff.create_distplot([np.random.randn(500)], group_labels = 'X', bin_size=.1)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5724/3147128641.py in <module>
#       1 x=np.random.seed(500)
# ----> 2 fig = ff.create_distplot([np.random.randn(500)], group_labels = 'X', bin_size=.1)
#       3 fig.show()
#
# NameError: name 'ff' is not defined

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 33. Using the 'tips' data from seaborn, plot a violin plot for 'tips' based on the 'sex'
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# initiate the figure
fig = go.Figure()

# plot the violin plot
# x specifies the data on x axis
# y specifies the data on y axis
# name is the label give to that side
# side specifies the side of the violin plot
# line_color sets the color of the plot

# plot tips given by females
fig.add_trace(go.Violin(x = tips['day'][ tips['sex'] == 'Female'],
                        y = tips['total_bill'][ tips['sex'] == 'Female'],
                        name='Yes',side = 'negative', line_color = 'blue'))

# plot tips given by males
fig.add_trace(go.Violin(x=tips['day'][ tips['sex'] == 'Male' ],
                        y=tips['total_bill'][ tips['sex'] == 'Male'],
                        name='No', side='positive', line_color='orange') )


# plot the mean line
fig.update_traces(meanline_visible=True)

# display the plot
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5724/3556389557.py in <module>
#       1 # initiate the figure
# ----> 2 fig = go.Figure()
#       3
#       4 # plot the violin plot
#       5 # x specifies the data on x axis
#
# NameError: name 'go' is not defined

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 34. Using the tips dataset from seaborn, plot a donut plot with legend representing the percentage of the tip got on that day
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df = px.data.tips()
fig = px.pie(df, values='tip', names='day')
fig.update_traces(hoverinfo='label', textfont_size=20, hole=.4,
               marker=dict(colors= ['gold', 'mediumturquoise', 'darkorange', 'lightgreen'],
                           line=dict(color='#000000', width=2)))

# display the plot
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5724/3469095791.py in <module>
# ----> 1 df = px.data.tips()
#       2 fig = px.pie(df, values='tip', names='day')
#       3 fig.update_traces(hoverinfo='label', textfont_size=20, hole=.4,
#       4                marker=dict(colors= ['gold', 'mediumturquoise', 'darkorange', 'lightgreen'],
#       5                            line=dict(color='#000000', width=2)))
#
# NameError: name 'px' is not defined

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b> 35. The exports and imports (in billion dollars) is given for a country from 2001 to 2005. Draw a barplot for the data
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# create a list of years
year = ['2001', '2002', '2003', '2004', '2005']

# create a list of imports
imports = (54.4, 53.8, 61.6, 74.15, 89.33)

# create a list of exports
exports = (42.5, 44.5, 48.3, 57.24, 69.18)

# %%
x = np.arange(len(year))

# set the bar width
width = 0.4

# initiate the plot
fig, ax = plt.subplots()

# set the bars
bars1 = ax.bar(x - width/2, imports, width, label='Imports')
bars2 = ax.bar(x + width/2, exports, width, label='Exports')

# add title for plot
plt.title('Imports and Exports from 2001-05')

# add label the axes
# add label to x-axis
plt.xlabel('Year')

# add label to y-axis
plt.ylabel('USD (in billions)')

# add xticks
plt.xticks([tick for tick in range(len(bars1))], year)

# add the legend
plt.legend()

# display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8240/3138120737.py in <module>
# ----> 1 x = np.arange(len(year))
#       2
#       3 # set the bar width
#       4 width = 0.4
#       5
#
# NameError: name 'year' is not defined

# %%
fig=go.Figure()
# plot the imports data
fig.add_trace(go.Bar(x = year, y = imports, name = 'Imports', marker_color = 'lightslategrey', text=imports,
            textposition='auto'))

# plot the exports data
fig.add_trace(go.Bar(x = year, y = exports, name='Exports', marker_color = 'crimson',text=exports,
            textposition='auto'))

# set the tickangle of the x-axis
fig.update_layout(barmode='group', xaxis_tickangle=-90)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8240/556592872.py in <module>
#       1 fig=go.Figure()
#       2 # plot the imports data
# ----> 3 fig.add_trace(go.Bar(x = year, y = imports, name = 'Imports', marker_color = 'lightslategrey', text=imports,
#       4             textposition='auto'))
#       5
#
# NameError: name 'year' is not defined
